# %%
from __future__ import annotations

import math
import os
import sys
import time as t
from datetime import date
from pathlib import Path
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import seaborn as sns

sys.path.append("../0-data") 
from archi_dict import archi_sorghum as archi_1
from archi_dict import archi_maize as archi_2

from openalea.archicrop.simulation import compute_extinction_coef, concat_usm

# %%
df_stics = pd.read_csv("../../1-simul_stics/2-outputs/simulations_stics_intercrops.csv")
df_stics["usm"] = df_stics["situation"]
df_stics["fapar_stics"] = df_stics["raint"] / (0.48 * 0.95 * df_stics["trg_n"])
df_stics = df_stics[df_stics["raint"] != 0.0]
df_stics = df_stics[df_stics["laimax"] != 0.0]
df_stics = df_stics[df_stics["hauteur"] != 0.0]
df_stics
# Out:
#       situation        Date  pla  somupvtsem   laimax  laisen_n  hauteur  \
# 208       usm_1  2018-07-06  mai   203.30836  0.00012   0.00000  0.01847
# 209       usm_1  2018-07-06  mai   203.30836  0.00012   0.00000  0.01847
# 212       usm_1  2018-07-07  mai   225.01837  0.00025   0.00000  0.02322
# 213       usm_1  2018-07-07  mai   225.01837  0.00025   0.00000  0.02322
# 214       usm_1  2018-07-07  sor   181.01837  0.00002   0.00000  0.01528
# ...         ...         ...  ...         ...      ...       ...      ...
# 41263     usm_9  2018-10-13  sor  1561.63757  4.43769   0.09140  2.49980
# 41264     usm_9  2018-10-14  mai  2216.54102  2.88442   2.93751  2.50000
# 41265     usm_9  2018-10-14  mai  2223.13452  2.88022   2.93336  2.50000
# 41266     usm_9  2018-10-14  sor  1572.56299  4.05810   0.10292  2.49979
# 41267     usm_9  2018-10-14  sor  1579.08459  4.43769   0.10343  2.49980
#
#          raint  trg_n  ilevs  iamfs  ilaxs   densite  demande    lai_n  \
# 208    0.00079   21.5    186    218    240   4.16667  0.01000  0.00012
# 209    0.00079   21.5    186    218    240   4.16667  0.01000  0.00012
# 212    0.00153   18.9    186    218    240   4.16667  0.01000  0.00025
# 213    0.00153   18.9    186    218    240   4.16667  0.01000  0.00025
# 214    0.00010   18.9    188    232    282   4.16667  0.01000  0.00002
# ...        ...    ...    ...    ...    ...       ...      ...      ...
# 41263  7.13167   19.2    188    232    282  11.11111  1.80876  4.38604
# 41264  1.73668   20.7    186    218    240  11.11111  0.69833  0.00000
# 41265  1.51072   20.7    186    218    240  11.11111  0.61417  0.00000
# 41266  7.40045   20.7    188    232    282  11.11111  1.98293  3.99535
# 41267  7.68367   20.7    188    232    282  11.11111  1.96432  4.37401
#
#          Plant   Dominance algorithm    usm  fapar_stics
# 208      maize  Associated      2.5D  usm_1     0.000081
# 209      maize  Associated      Beer  usm_1     0.000081
# 212      maize  Associated      2.5D  usm_1     0.000178
# 213      maize  Associated      Beer  usm_1     0.000178
# 214    sorghum   Principal      Beer  usm_1     0.000012
# ...        ...         ...       ...    ...          ...
# 41263  sorghum   Principal      Beer  usm_9     0.814564
# 41264    maize  Associated      2.5D  usm_9     0.183986
# 41265    maize  Associated      Beer  usm_9     0.160047
# 41266  sorghum   Principal      2.5D  usm_9     0.784012
# 41267  sorghum   Principal      Beer  usm_9     0.814017
#
# [18666 rows x 20 columns]

# %%
sns.relplot(
    data=df_stics,
    x="Date", 
    y="fapar_stics",
    hue="usm",
    row="Plant",
    col="algorithm",
    style="densite",
    kind="line",
)

'''
g = sns.relplot(
    data=fmri,
    x="timepoint", y="signal",
    hue="event", style="event", col="region",
    height=4, aspect=.7, kind="line"
)
(g.map(plt.axhline, y=0, color=".7", dashes=(2, 1), zorder=0)
  .set_axis_labels("Timepoint", "Percent signal change")
  .set_titles("Region: {col_name} cortex")
  .tight_layout(w_pad=0))
'''
# Out:
# '\ng = sns.relplot(\n    data=fmri,\n    x="timepoint", y="signal",\n    hue="event", style="event", col="region",\n    height=4, aspect=.7, kind="line"\n)\n(g.map(plt.axhline, y=0, color=".7", dashes=(2, 1), zorder=0)\n  .set_axis_labels("Timepoint", "Percent signal change")\n  .set_titles("Region: {col_name} cortex")\n  .tight_layout(w_pad=0))\n'

# %%
df_doe = pd.read_csv("../../1-simul_stics/2-outputs/doe.csv")

df_doe["usm"] = [f"usm_{i}" for i in range(1,len(df_doe)+1)]

df_doe
# Out:
#             species_id species_principal species_secondary  \
# 0   sorghum-maize_trop           sorghum        maize_trop
# 1   sorghum-maize_trop           sorghum        maize_trop
# 2   sorghum-maize_trop           sorghum        maize_trop
# 3   sorghum-maize_trop           sorghum        maize_trop
# 4   sorghum-maize_trop           sorghum        maize_trop
# 5   sorghum-maize_trop           sorghum        maize_trop
# 6   sorghum-maize_trop           sorghum        maize_trop
# 7   sorghum-maize_trop           sorghum        maize_trop
# 8   sorghum-maize_trop           sorghum        maize_trop
# 9   sorghum-maize_trop           sorghum        maize_trop
# 10  sorghum-maize_trop           sorghum        maize_trop
# 11  sorghum-maize_trop           sorghum        maize_trop
# 12  sorghum-maize_trop           sorghum        maize_trop
# 13  sorghum-maize_trop           sorghum        maize_trop
# 14  sorghum-maize_trop           sorghum        maize_trop
# 15  sorghum-maize_trop           sorghum        maize_trop
# 16  sorghum-maize_trop           sorghum        maize_trop
# 17  sorghum-maize_trop           sorghum        maize_trop
# 18  sorghum-maize_trop           sorghum        maize_trop
# 19  sorghum-maize_trop           sorghum        maize_trop
# 20  sorghum-maize_trop           sorghum        maize_trop
# 21  sorghum-maize_trop           sorghum        maize_trop
# 22  sorghum-maize_trop           sorghum        maize_trop
# 23  sorghum-maize_trop           sorghum        maize_trop
# 24  sorghum-maize_trop           sorghum        maize_trop
# 25  sorghum-maize_trop           sorghum        maize_trop
# 26  sorghum-maize_trop           sorghum        maize_trop
# 27  sorghum-maize_trop           sorghum        maize_trop
# 28  sorghum-maize_trop           sorghum        maize_trop
# 29  sorghum-maize_trop           sorghum        maize_trop
# 30  sorghum-maize_trop           sorghum        maize_trop
# 31  sorghum-maize_trop           sorghum        maize_trop
# 32  sorghum-maize_trop           sorghum        maize_trop
# 33  sorghum-maize_trop           sorghum        maize_trop
# 34  sorghum-maize_trop           sorghum        maize_trop
# 35  sorghum-maize_trop           sorghum        maize_trop
# 36  sorghum-maize_trop           sorghum        maize_trop
# 37  sorghum-maize_trop           sorghum        maize_trop
# 38  sorghum-maize_trop           sorghum        maize_trop
# 39  sorghum-maize_trop           sorghum        maize_trop
# 40  sorghum-maize_trop           sorghum        maize_trop
# 41  sorghum-maize_trop           sorghum        maize_trop
# 42  sorghum-maize_trop           sorghum        maize_trop
# 43  sorghum-maize_trop           sorghum        maize_trop
# 44  sorghum-maize_trop           sorghum        maize_trop
#
#                  design row_orientation interrow_distance_principal  \
# 0       intercrop mixed             N-S                      middle
# 1       intercrop mixed             N-S                      middle
# 2       intercrop mixed             N-S                      middle
# 3   intercrop alternate             N-S                        high
# 4   intercrop alternate             N-S                      middle
# 5   intercrop alternate             N-S                         low
# 6   intercrop alternate             E-W                        high
# 7   intercrop alternate             E-W                      middle
# 8   intercrop alternate             E-W                         low
# 9      intercrop strips             N-S                      middle
# 10     intercrop strips             N-S                      middle
# 11     intercrop strips             N-S                      middle
# 12     intercrop strips             N-S                      middle
# 13     intercrop strips             N-S                      middle
# 14     intercrop strips             N-S                      middle
# 15     intercrop strips             N-S                      middle
# 16     intercrop strips             N-S                      middle
# 17     intercrop strips             N-S                      middle
# 18     intercrop strips             N-S                      middle
# 19     intercrop strips             N-S                      middle
# 20     intercrop strips             N-S                      middle
# 21     intercrop strips             N-S                      middle
# 22     intercrop strips             N-S                      middle
# 23     intercrop strips             N-S                      middle
# 24     intercrop strips             N-S                      middle
# 25     intercrop strips             N-S                      middle
# 26     intercrop strips             N-S                      middle
# 27     intercrop strips             E-W                      middle
# 28     intercrop strips             E-W                      middle
# 29     intercrop strips             E-W                      middle
# 30     intercrop strips             E-W                      middle
# 31     intercrop strips             E-W                      middle
# 32     intercrop strips             E-W                      middle
# 33     intercrop strips             E-W                      middle
# 34     intercrop strips             E-W                      middle
# 35     intercrop strips             E-W                      middle
# 36     intercrop strips             E-W                      middle
# 37     intercrop strips             E-W                      middle
# 38     intercrop strips             E-W                      middle
# 39     intercrop strips             E-W                      middle
# 40     intercrop strips             E-W                      middle
# 41     intercrop strips             E-W                      middle
# 42     intercrop strips             E-W                      middle
# 43     intercrop strips             E-W                      middle
# 44     intercrop strips             E-W                      middle
#
#    interrow_distance_secondary n_rows_principal n_rows_secondary  \
# 0                       middle              one              one
# 1                       middle              one              one
# 2                       middle              one              one
# 3                         high              one              one
# 4                       middle              one              one
# 5                          low              one              one
# 6                         high              one              one
# 7                       middle              one              one
# 8                          low              one              one
# 9                       middle             high             high
# 10                      middle             high             high
# 11                      middle             high           middle
# 12                      middle             high           middle
# 13                      middle             high              low
# 14                      middle             high              low
# 15                      middle           middle             high
# 16                      middle           middle             high
# 17                      middle           middle           middle
# 18                      middle           middle           middle
# 19                      middle           middle              low
# 20                      middle           middle              low
# 21                      middle              low             high
# 22                      middle              low             high
# 23                      middle              low           middle
# 24                      middle              low           middle
# 25                      middle              low              low
# 26                      middle              low              low
# 27                      middle             high             high
# 28                      middle             high             high
# 29                      middle             high           middle
# 30                      middle             high           middle
# 31                      middle             high              low
# 32                      middle             high              low
# 33                      middle           middle             high
# 34                      middle           middle             high
# 35                      middle           middle           middle
# 36                      middle           middle           middle
# 37                      middle           middle              low
# 38                      middle           middle              low
# 39                      middle              low             high
# 40                      middle              low             high
# 41                      middle              low           middle
# 42                      middle              low           middle
# 43                      middle              low              low
# 44                      middle              low              low
#
#    intrarow_distance sowing_date_latest_crop     usm
# 0               high                    same   usm_1
# 1             middle                    same   usm_2
# 2                low                    same   usm_3
# 3             middle                    same   usm_4
# 4             middle                    same   usm_5
# 5             middle                    same   usm_6
# 6             middle                    same   usm_7
# 7             middle                    same   usm_8
# 8             middle                    same   usm_9
# 9             middle                    same  usm_10
# 10            middle                   later  usm_11
# 11            middle                    same  usm_12
# 12            middle                   later  usm_13
# 13            middle                    same  usm_14
# 14            middle                   later  usm_15
# 15            middle                    same  usm_16
# 16            middle                   later  usm_17
# 17            middle                    same  usm_18
# 18            middle                   later  usm_19
# 19            middle                    same  usm_20
# 20            middle                   later  usm_21
# 21            middle                    same  usm_22
# 22            middle                   later  usm_23
# 23            middle                    same  usm_24
# 24            middle                   later  usm_25
# 25            middle                    same  usm_26
# 26            middle                   later  usm_27
# 27            middle                    same  usm_28
# 28            middle                   later  usm_29
# 29            middle                    same  usm_30
# 30            middle                   later  usm_31
# 31            middle                    same  usm_32
# 32            middle                   later  usm_33
# 33            middle                    same  usm_34
# 34            middle                   later  usm_35
# 35            middle                    same  usm_36
# 36            middle                   later  usm_37
# 37            middle                    same  usm_38
# 38            middle                   later  usm_39
# 39            middle                    same  usm_40
# 40            middle                   later  usm_41
# 41            middle                    same  usm_42
# 42            middle                   later  usm_43
# 43            middle                    same  usm_44
# 44            middle                   later  usm_45

# %%
directory = Path("../0-data/")

for i,file in enumerate(directory.glob("*.csv")):

    # Read the CSV file
    df = pd.read_csv(file)
    
    # Keep only maize and sorghum
    crop_df = df[df["group"].isin(["maize", "sorghum"])]
    
    # Calculate average fAPAR for each group at each time step
    average_fapar = (
        crop_df
        .groupby(["group", "step_number"], as_index=False)["fapar"]
        # .mean()
        .sum()
        .rename(columns={"fapar": "sum_fapar"})
    )

    fn = Path(file).stem
    u = re.search(r"usm_\d+", fn).group()
    average_fapar["usm"] = u
    average_fapar["algo"] = "2.5D" if i%2==0 else "Beer"

    if i==0:
        conc_df = average_fapar
    else:
        conc_df = pd.concat([conc_df, average_fapar], ignore_index=True)
        

    # print(average_fapar)

# %%
conc_df
# Out:
#          group  step_number  sum_fapar     usm  algo
# 0        maize            1   0.000977  usm_10  2.5D
# 1        maize            2   0.001464  usm_10  2.5D
# 2        maize            3   0.002019  usm_10  2.5D
# 3        maize            4   0.002865  usm_10  2.5D
# 4        maize            5   0.003933  usm_10  2.5D
# ...        ...          ...        ...     ...   ...
# 18170  sorghum           98   0.911272   usm_9  Beer
# 18171  sorghum           99   0.911317   usm_9  Beer
# 18172  sorghum          100   0.911588   usm_9  Beer
# 18173  sorghum          101   0.911455   usm_9  Beer
# 18174  sorghum          102   0.911545   usm_9  Beer
#
# [18175 rows x 5 columns]

# %%
merged = pd.merge(conc_df, df_doe, on="usm")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 merged = pd.merge(conc_df, df_doe, on="usm")
#
# NameError: name 'df_doe' is not defined

# %%
merged

# %%
dist = {"low":0.2, "middle":0.4, "high":0.8}
n_rows = {"one":1, "low":2, "middle":4, "high":6}

merged["species"] = merged["group"]
merged["DAE"] = merged["step_number"]
merged["interrow_sorghum"] = [dist[i] for i in merged["interrow_distance_principal"]] 
merged["interrow_maize"] = [dist[i] for i in merged["interrow_distance_secondary"]]
merged["intrarow"] = [dist[i] for i in merged["intrarow_distance"]]
merged["n_rows_sorghum"] = [n_rows[i] for i in merged["n_rows_principal"]]
merged["n_rows_maize"] = [n_rows[i] for i in merged["n_rows_secondary"]]
merged["density_sorghum"] = 1/merged["interrow_sorghum"]/merged["intrarow"]
merged["density_maize"] = 1/merged["interrow_maize"]/merged["intrarow"]
# merged["nb_plants_sorghum"] = [2 if merged.iloc[i]["design"] == "intercrop mixed" else merged.iloc[i]["n_rows_sorghum"] for i in range(len(merged))]
# merged["nb_plants_maize"] = [2 if merged.iloc[i]["design"] == "intercrop mixed" else merged.iloc[i]["n_rows_maize"] for i in range(len(merged))]
merged["width"] = [2 * merged.iloc[i]["interrow_sorghum"] if merged.iloc[i]["design"] == "intercrop mixed" else (merged.iloc[i]["n_rows_sorghum"]-1) * merged.iloc[i]["interrow_sorghum"] + (merged.iloc[i]["n_rows_maize"]-1) * merged.iloc[i]["interrow_maize"] + 2*max(merged.iloc[i]["interrow_sorghum"], merged.iloc[i]["interrow_maize"]) for i in range(len(merged))]
merged["length"] = [2 * max(merged.iloc[i]["intrarow"], merged.iloc[i]["intrarow"]) if merged.iloc[i]["design"] == "intercrop mixed" else max(merged.iloc[i]["intrarow"], merged.iloc[i]["intrarow"]) for i in range(len(merged))]
merged["domain_area"] = merged["width"] * merged["length"]
merged["fapar_crop"] = merged["sum_fapar"] / merged["domain_area"]

merged

# %%
merged = merged.drop(columns=["species_id","species_principal","species_secondary","group"])
merged

# %%
simultaneous = merged[merged["sowing_date_latest_crop"] == "same"]

plot = sns.relplot(
    data=simultaneous,
    x="DAE", 
    y="sum_fapar",
    hue="design",
    row="species",
    col="algo",
    kind="line",
)

plot.savefig('../2-outputs/light_designs.png')

# %%
simultaneous

# %%
plot = sns.relplot(
    data=simultaneous,
    x="DAE", 
    y="sum_fapar",
    hue="usm",
    row="species",
    col="algo",
    kind="line",
)

# %%
plot = sns.relplot(
    data=simultaneous,
    x="DAE", 
    y="sum_fapar",
    hue="row_orientation",
    row="species",
    col="algo",
    kind="line",
)

# %%
plot = sns.relplot(
    data=simultaneous,
    x="DAE", 
    y="sum_fapar",
    hue="density_sorghum",
    row="species",
    col="algo",
    kind="line",
)

# %%
plot = sns.relplot(
    data=simultaneous,
    x="DAE", 
    y="sum_fapar",
    hue="density_maize",
    row="species",
    col="algo",
    kind="line",
)
